// %%
import scala.collection.mutable.ArrayBuffer

case class widgetdata(Count: Int, Count_plus1: Int, Count_mult: Int)

val out = new ArrayBuffer[widgetdata]

for (i <- 0 to 100) {
  out += widgetdata(i, i+1, i*i)
}

out
// Out:
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anona79abf30722c65691fd2ccd023ae70a7&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;604414666&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul604414666"><li>
//               <a href="#tab604414666-0"><i class="fa fa-table"/></a>
//             </li><li>
// ...

// %%
out
// Out:
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon5151a76dbe12ae7cb9ae04e4133360ab&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;611170875&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul611170875"><li>
//               <a href="#tab611170875-0"><i class="fa fa-table"/></a>
//             </li><li>
// ...
